# %% [markdown]
# <a href="https://colab.research.google.com/github/jfink09/Medical-Related-Projects/blob/main/SMILE_Calculation_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sphere perscription values
sph = [0,-0.25,-0.50,-0.75,-1.00,
       -1.25,-1.50,-1.75,-2.00,
       -2.25,-2.50,-2.75,-3.00,
       -3.25,-3.50,-3.75,-4.00,
       -4.25,-4.50,-4.75,-5.00,
       -5.25,-5.50,-5.75,-6.00,
       -6.25,-6.50,-6.75,-7.00,
       -7.25,-7.50,-7.75,-8.00,
       -8.25,-8.50,-8.75,-9.00,
       -9.25,-9.50,-9.75,-10.00]

# %%
from numpy import *

# Cylinder perscription values
cyl = [0,-0.25,-0.50,-0.75,-1.00,
       -1.25,-1.50,-1.75,-2.00,
       -2.25,-2.50,-2.75,-3.00]
       
cyl = linspace(0,-3,41) # Create 41 cylinder values from 0 to -3.00

cyl
# Out:
# array([ 0.   , -0.075, -0.15 , -0.225, -0.3  , -0.375, -0.45 , -0.525,
#        -0.6  , -0.675, -0.75 , -0.825, -0.9  , -0.975, -1.05 , -1.125,
#        -1.2  , -1.275, -1.35 , -1.425, -1.5  , -1.575, -1.65 , -1.725,
#        -1.8  , -1.875, -1.95 , -2.025, -2.1  , -2.175, -2.25 , -2.325,
#        -2.4  , -2.475, -2.55 , -2.625, -2.7  , -2.775, -2.85 , -2.925,
#        -3.   ])

# %%
len(sph), len(cyl)
# Out:
# (41, 41)

# %%
# Columns of SMILE table
col_1 = [0,0,0,0,29,
         32,36,39,42,46,
         49,52,55,59,62,
         65,68,71,74,77,
         80,83,86,89,92,
         95,98,101,104,107,
         110,112,115,118,121,
         123,126,129,132,134,
         137]

col_2 = [0,0,0,0,43,
         47,51,55,59,63,
         67,70,74,78,82,
         85,89,93,96,100,
         103,107,111,114,118,
         121,124,128,131,134,
         138,141,144,148,151,
         154,157,160,164,167,
         170]

col_3 = [0,0,0,0,47,
         51,55,59,62,66,
         70,74,78,81,85,
         89,92,96,100,103,
         107,110,114,117,121,
         124,128,131,134,138,
         141,144,147,151,154,
         157,160,163,167,170,
         173]

col_4 = [0,0,0,0,50,
         54,58,62,66,70,
         74,77,81,85,89,
         92,96,99,103,107,
         110,114,117,121,124,
         127,131,134,137,141,
         144,147,151,154,157,
         160,163,166,170,173,
         176]

col_5 = [0,0,0,0,54,
         58,62,66,70,73,
         77,81,85,88,92,
         96,99,103,106,110,
         113,117,120,124,127,
         131,134,137,141,144,
         147,150,154,157,160,
         163,166,169,173,176,
         179]

col_6 = [0,0,0,0,59,
         62,66,69,73,77,
         81,84,88,92,95,
         99,103,106,110,113,
         117,120,124,127,130,
         134,137,140,144,147,
         150,153,157,160,163,
         166,169,172,175,178,
         182]

col_7 = [0,0,0,0,61,
         65,69,73,77,80,
         84,88,92,95,99,
         102,106,110,113,117,
         120,123,127,130,134,
         137,140,144,147,150,
         153,157,160,163,166,
         169,172,175,178,181,
         184]

col_8 = [0,0,0,0,65,
         69,73,76,80,84,
         88,91,95,99,102,
         106,109,113,116,120,
         123,127,130,133,137,
         140,143,147,150,143,
         156,160,163,166,169,
         172,175,178,181,184,
         0]

col_9 = [0,0,0,0,69,
         72,76,80,84,87,
         91,95,98,102,106,
         109,113,116,120,123,
         126,130,133,137,140,
         143,146,150,153,156,
         159,163,166,169,172,
         175,178,181,184,187,
         0]
         
col_10 = [0,0,0,0,72,
          76,80,83,87,91,
          95,98,102,105,109,
          112,116,119,123,126,
          130,133,136,140,143,
          146,150,153,156,159,
          162,166,169,172,175,
          178,181,184,187,0,
          0]

col_11 = [0,0,0,0,76,
          80,83,87,91,94,
          98,102,105,109,112,
          116,119,123,126,129,
          133,136,140,143,146,
          149,153,156,159,162,
          165,168,172,175,178,
          181,184,187,190,0,
          0]

# col_1[col_1==0 ] = np.nan
# col_2[col_2==0 ] = np.nan
# col_3[col_3==0 ] = np.nan
# col_4[col_4==0 ] = np.nan
# col_5[col_5==0 ] = np.nan
# col_6[col_6==0 ] = np.nan
# col_7[col_7==0 ] = np.nan
# col_8[col_8==0 ] = np.nan
# col_9[col_9==0 ] = np.nan
# col_10[col_10==0 ] = np.nan
# col_11[col_11==0 ] = np.nan
def zero_to_nan(col_1):
    """Replace every 0 with 'nan' and return a copy."""
    return [float('nan') if x==0 else x for x in col_1]

print(zero_to_nan(col_1))
# Out:
# [nan, nan, nan, nan, 29, 32, 36, 39, 42, 46, 49, 52, 55, 59, 62, 65, 68, 71, 74, 77, 80, 83, 86, 89, 92, 95, 98, 101, 104, 107, 110, 112, 115, 118, 121, 123, 126, 129, 132, 134, 137]

# %%
len(col_1), len(col_2), len(col_3), len(col_4), len(col_5), len(col_6), len(col_7), len(col_8), len(col_9), len(col_10), len(col_11)
# Out:
# (41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41)

# %%
from matplotlib.legend_handler import cycle
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining 2 axes
z = cyl
x = sph

# plotting
ax.scatter(x, zero_to_nan(col_1), z, label="Cyl 0.00")
ax.scatter(x, zero_to_nan(col_2), z, label="Cyl -0.75")
ax.scatter(x, zero_to_nan(col_3), z, label="Cyl -1.00")
ax.scatter(x, zero_to_nan(col_4), z, label="Cyl -1.25")
ax.scatter(x, zero_to_nan(col_5), z, label="Cyl -1.50")
ax.scatter(x, zero_to_nan(col_6), z, label="Cyl -1.75")
ax.scatter(x, zero_to_nan(col_7), z, label="Cyl -2.00")
ax.scatter(x, zero_to_nan(col_8), z, label="Cyl -2.25")
ax.scatter(x, zero_to_nan(col_9), z, label="Cyl -2.50")
ax.scatter(x, zero_to_nan(col_10), z, label="Cyl -2.75")
ax.scatter(x, zero_to_nan(col_11), z, label="Cyl -3.00")

ax.set_title('3D line plot')
ax.axes.set_xlabel("Sphere")
ax.axes.set_ylabel("Columns")
ax.axes.set_zlabel("Cylinder")
ax.legend()

ax.view_init(-120, 90)

plt.show()

# %%
from matplotlib.legend_handler import cycle
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining 2 axes
z = cyl
x = sph

# plotting
ax.scatter(x, zero_to_nan(col_1), z, label="Cyl 0.00")
ax.scatter(x, zero_to_nan(col_2), z, label="Cyl -0.75")
ax.scatter(x, zero_to_nan(col_3), z, label="Cyl -1.00")
ax.scatter(x, zero_to_nan(col_4), z, label="Cyl -1.25")
ax.scatter(x, zero_to_nan(col_5), z, label="Cyl -1.50")
ax.scatter(x, zero_to_nan(col_6), z, label="Cyl -1.75")
ax.scatter(x, zero_to_nan(col_7), z, label="Cyl -2.00")
ax.scatter(x, zero_to_nan(col_8), z, label="Cyl -2.25")
ax.scatter(x, zero_to_nan(col_9), z, label="Cyl -2.50")
ax.scatter(x, zero_to_nan(col_10), z, label="Cyl -2.75")
ax.scatter(x, zero_to_nan(col_11), z, label="Cyl -3.00")

ax.set_title('3D line plot')
ax.axes.set_xlabel("Sphere")
ax.axes.set_ylabel("Columns")
ax.axes.set_zlabel("Cylinder")
ax.legend()

ax.view_init(-140, 60)

plt.show()

# %%
from matplotlib.legend_handler import cycle
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from numpy.polynomial.polynomial import polyfit

fig = plt.figure(figsize=(15,10))

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining 2 axes
z = cyl
x = sph

# plotting
ax.scatter(x, zero_to_nan(col_1), z, label="Cyl 0.00")
ax.scatter(x, zero_to_nan(col_2), z, label="Cyl -0.75")
ax.scatter(x, zero_to_nan(col_3), z, label="Cyl -1.00")
ax.scatter(x, zero_to_nan(col_4), z, label="Cyl -1.25")
ax.scatter(x, zero_to_nan(col_5), z, label="Cyl -1.50")
ax.scatter(x, zero_to_nan(col_6), z, label="Cyl -1.75")
ax.scatter(x, zero_to_nan(col_7), z, label="Cyl -2.00")
ax.scatter(x, zero_to_nan(col_8), z, label="Cyl -2.25")
ax.scatter(x, zero_to_nan(col_9), z, label="Cyl -2.50")
ax.scatter(x, zero_to_nan(col_10), z, label="Cyl -2.75")
ax.scatter(x, zero_to_nan(col_11), z, label="Cyl -3.00")

ax.set_title('3D line plot')
ax.axes.set_xlabel("Sphere")
ax.axes.set_ylabel("Columns")
ax.axes.set_zlabel("Cylinder")
ax.legend()

ax.view_init(0, 180)

plt.show()

# %%
from matplotlib.legend_handler import cycle
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining 2 axes
z = cyl
x = sph

# plotting
ax.scatter(x, zero_to_nan(col_1), z, label="Cyl 0.00")
ax.scatter(x, zero_to_nan(col_2), z, label="Cyl -0.75")
ax.scatter(x, zero_to_nan(col_3), z, label="Cyl -1.00")
ax.scatter(x, zero_to_nan(col_4), z, label="Cyl -1.25")
ax.scatter(x, zero_to_nan(col_5), z, label="Cyl -1.50")
ax.scatter(x, zero_to_nan(col_6), z, label="Cyl -1.75")
ax.scatter(x, zero_to_nan(col_7), z, label="Cyl -2.00")
ax.scatter(x, zero_to_nan(col_8), z, label="Cyl -2.25")
ax.scatter(x, zero_to_nan(col_9), z, label="Cyl -2.50")
ax.scatter(x, zero_to_nan(col_10), z, label="Cyl -2.75")
ax.scatter(x, zero_to_nan(col_11), z, label="Cyl -3.00")

ax.set_title('3D line plot')
ax.axes.set_xlabel("Sphere")
ax.axes.set_ylabel("Columns")
ax.axes.set_zlabel("Cylinder")
ax.legend()

ax.view_init(0, 90)

plt.show()

# %%
from matplotlib.legend_handler import cycle
# importing mplot3d toolkits, numpy and matplotlib
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

# syntax for 3-D projection
ax = plt.axes(projection ='3d')

# defining 2 axes
z = cyl
x = sph

# plotting
ax.scatter(x, zero_to_nan(col_1), z, label="Cyl 0.00")
ax.scatter(x, zero_to_nan(col_2), z, label="Cyl -0.75")
ax.scatter(x, zero_to_nan(col_3), z, label="Cyl -1.00")
ax.scatter(x, zero_to_nan(col_4), z, label="Cyl -1.25")
ax.scatter(x, zero_to_nan(col_5), z, label="Cyl -1.50")
ax.scatter(x, zero_to_nan(col_6), z, label="Cyl -1.75")
ax.scatter(x, zero_to_nan(col_7), z, label="Cyl -2.00")
ax.scatter(x, zero_to_nan(col_8), z, label="Cyl -2.25")
ax.scatter(x, zero_to_nan(col_9), z, label="Cyl -2.50")
ax.scatter(x, zero_to_nan(col_10), z, label="Cyl -2.75")
ax.scatter(x, zero_to_nan(col_11), z, label="Cyl -3.00")

ax.set_title('3D line plot')
ax.axes.set_xlabel("Sphere")
ax.axes.set_ylabel("Columns")
ax.axes.set_zlabel("Cylinder")
ax.legend()

ax.view_init(90, 0)

plt.show()
